# %% [markdown]
# <a href="https://colab.research.google.com/github/Slim205/ABM-prediction/blob/main/Challenge_Data_QRT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # QRT ENS Data Challenge 2023 - Benchmark (english)
#
# This notebook details the benchmark construction for the challenge - it may also help participants to start the competition.
#
# ## Libraries

# %%
import numpy as np
import pandas as pd
from scipy.stats import spearmanr
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading data
#
# - `X_train` and `X_test` both have $35$ columns that represent the same explanatory variables but over different time periods.
#
# - `X_train` and `Y_train` share the same column `ID` - each row corresponds to a unique ID associated wwith a day and a country.
#
# - The target of this challenge `TARGET` in `Y_train` corresponds to the price change for daily futures contracts of 24H electricity baseload.
#
# - **You will notice some columns have missing values**.

# %%
# After downloading the X_train/X_test/Y_train .csv files in your working directory:
from google.colab import drive
drive.mount('/content/drive')

X_train = pd.read_csv('/content/drive/MyDrive/X_train.csv')
Y_train = pd.read_csv('/content/drive/MyDrive/Y_train.csv')
X_test = pd.read_csv('/content/drive/MyDrive/X_test_final.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
X_train.head()
# Out:
#      ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 0  1054     206      FR        0.210099       -0.427458       -0.606523
# 1  2049     501      FR       -0.022399       -1.003452       -0.022063
# 2  1924     687      FR        1.395035        1.978665        1.021305
# 3   297     720      DE       -0.983324       -0.849198       -0.839586
# 4  1101     818      FR        0.143807       -0.617038       -0.924990
#
#    FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  ...  \
# 0        0.606523            NaN       0.692860            NaN  ...
# 1        0.022063      -0.573520      -1.130838       0.573520  ...
# 2       -1.021305      -0.622021      -1.682587       0.622021  ...
# 3        0.839586      -0.270870       0.563230       0.270870  ...
# 4        0.924990            NaN       0.990324            NaN  ...
#
#    FR_RESIDUAL_LOAD   DE_RAIN   FR_RAIN   DE_WIND   FR_WIND   DE_TEMP  \
# 0         -0.444661 -0.172680 -0.556356 -0.790823 -0.283160 -1.069070
# 1         -1.183194 -1.240300 -0.770457  1.522331  0.828412  0.437419
# 2          1.947273 -0.480700 -0.313338  0.431134  0.487608  0.684884
# 3         -0.976974 -1.114838 -0.507570 -0.499409 -0.236249  0.350938
# 4         -0.526267 -0.541465 -0.424550 -1.088158 -1.011560  0.614338
#
#     FR_TEMP   GAS_RET  COAL_RET  CARBON_RET
# 0 -0.063404  0.339041  0.124552   -0.002445
# 1  1.831241 -0.659091  0.047114   -0.490365
# 2  0.114836  0.535974  0.743338    0.204952
# 3 -0.417514  0.911652 -0.296168    1.073948
# 4  0.729495  0.245109  1.526606    2.614378
#
# [5 rows x 35 columns]

# %%
Y_train.head()
# Out:
#      ID    TARGET
# 0  1054  0.028313
# 1  2049 -0.112516
# 2  1924 -0.180840
# 3   297 -0.260356
# 4  1101 -0.071733

# %% [markdown]
# ## Model and train score
#
# The benchark for this challenge consists in a simple linear regression, after a light cleaning of the data: The missing (NaN) values are simply filled with 0's and the `COUNTRY` column is dropped - namely we used the same model for France and Germany.

# %%
X_train_clean = X_train.drop(['COUNTRY'], axis=1).fillna(0)
Y_train_clean = Y_train['TARGET']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
Xtrain = scaler.fit_transform(X_train_clean)

# %%
import tensorflow as tf
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, input_shape=(34,) ,activation="relu"),
    tf.keras.layers.Dense(64,activation="relu"),
    tf.keras.layers.Dense(32,activation="relu"),
    tf.keras.layers.Dense(1)
])


model.compile(optimizer='adam', loss='mean_squared_error')
# Train the model
model.fit(Xtrain, Y_train_clean,epochs=160)
# Out:
# Epoch 1/160
# 47/47 [==============================] - 1s 10ms/step - loss: 1.0966
# Epoch 2/160
# 47/47 [==============================] - 0s 2ms/step - loss: 1.0234
# Epoch 3/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.9927
# Epoch 4/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.9738
# Epoch 5/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.9500
# Epoch 6/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.9254
# Epoch 7/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.9029
# Epoch 8/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.8791
# Epoch 9/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.8588
# Epoch 10/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.8393
# Epoch 11/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.8007
# Epoch 12/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.7932
# Epoch 13/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.7599
# Epoch 14/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.7464
# Epoch 15/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.7122
# Epoch 16/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6870
# Epoch 17/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6827
# Epoch 18/160
# 47/47 [==============================] - 0s 4ms/step - loss: 0.6566
# Epoch 19/160
# 47/47 [==============================] - 0s 4ms/step - loss: 0.6327
# Epoch 20/160
# 47/47 [==============================] - 0s 4ms/step - loss: 0.6097
# Epoch 21/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5945
# Epoch 22/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5861
# Epoch 23/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5501
# Epoch 24/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5370
# Epoch 25/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5110
# Epoch 26/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4936
# Epoch 27/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4769
# Epoch 28/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4666
# Epoch 29/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4310
# Epoch 30/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4369
# Epoch 31/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3977
# Epoch 32/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4020
# Epoch 33/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3731
# Epoch 34/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3539
# Epoch 35/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3455
# Epoch 36/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3320
# Epoch 37/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3283
# Epoch 38/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3092
# Epoch 39/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2905
# Epoch 40/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2929
# Epoch 41/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2725
# Epoch 42/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2579
# Epoch 43/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2438
# Epoch 44/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2314
# Epoch 45/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2349
# Epoch 46/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2358
# Epoch 47/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.2137
# Epoch 48/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1982
# Epoch 49/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1824
# Epoch 50/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1758
# Epoch 51/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1728
# Epoch 52/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1623
# Epoch 53/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1641
# Epoch 54/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1517
# Epoch 55/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1443
# Epoch 56/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.1444
# Epoch 57/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1352
# Epoch 58/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1284
# Epoch 59/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1205
# Epoch 60/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1163
# Epoch 61/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1138
# Epoch 62/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1087
# Epoch 63/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1055
# Epoch 64/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1044
# Epoch 65/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0966
# Epoch 66/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0940
# Epoch 67/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0902
# Epoch 68/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0836
# Epoch 69/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0829
# Epoch 70/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0765
# Epoch 71/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0762
# Epoch 72/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0791
# Epoch 73/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0786
# Epoch 74/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0709
# Epoch 75/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0698
# Epoch 76/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0783
# Epoch 77/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0628
# Epoch 78/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0589
# Epoch 79/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0544
# Epoch 80/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0571
# Epoch 81/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0562
# Epoch 82/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0502
# Epoch 83/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0501
# Epoch 84/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0471
# Epoch 85/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0575
# Epoch 86/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0520
# Epoch 87/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0478
# Epoch 88/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0455
# Epoch 89/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0404
# Epoch 90/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0449
# Epoch 91/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0442
# Epoch 92/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0361
# Epoch 93/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0392
# Epoch 94/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0391
# Epoch 95/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0388
# Epoch 96/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0432
# Epoch 97/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0336
# Epoch 98/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 99/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0323
# Epoch 100/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0361
# Epoch 101/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0357
# Epoch 102/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0318
# Epoch 103/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0275
# Epoch 104/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0256
# Epoch 105/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0278
# Epoch 106/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0302
# Epoch 107/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0321
# Epoch 108/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0241
# Epoch 109/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0236
# Epoch 110/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0294
# Epoch 111/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0262
# Epoch 112/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 113/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0267
# Epoch 114/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0259
# Epoch 115/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0262
# Epoch 116/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0276
# Epoch 117/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0268
# Epoch 118/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0220
# Epoch 119/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0229
# Epoch 120/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0226
# Epoch 121/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 122/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0368
# Epoch 123/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0357
# Epoch 124/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0359
# Epoch 125/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0303
# Epoch 126/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0280
# Epoch 127/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0293
# Epoch 128/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0242
# Epoch 129/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0206
# Epoch 130/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0271
# Epoch 131/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 132/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0287
# Epoch 133/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0334
# Epoch 134/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0211
# Epoch 135/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0215
# Epoch 136/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0160
# Epoch 137/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0186
# Epoch 138/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0162
# Epoch 139/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0236
# Epoch 140/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0166
# Epoch 141/160
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0313
# Epoch 142/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0280
# Epoch 143/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0342
# Epoch 144/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0284
# Epoch 145/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0329
# Epoch 146/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0303
# Epoch 147/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0229
# Epoch 148/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0212
# Epoch 149/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0270
# Epoch 150/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0197
# Epoch 151/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0170
# Epoch 152/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 153/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0175
# Epoch 154/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0207
# Epoch 155/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0198
# Epoch 156/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0276
# Epoch 157/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0232
# Epoch 158/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0209
# Epoch 159/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0194
# Epoch 160/160
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0147

# %%
output_train = model.predict(Xtrain)
def metric_train(output):

    return  spearmanr(output, Y_train_clean).correlation

print('Spearman correlation for the train set: {:.1f}%'.format(100 * metric_train(output_train) ))
# Out:
# 47/47 [==============================] - 0s 1ms/step
# Spearman correlation for the train set: 96.4%

# %% [markdown]
# The Spearman correlation obtained with our model on the train data set is about 27.9%.
#
# NB: Electricity price variations can be quite volatile and this is why we have chosen the Spearman rank correlation as a robust metric for the challenge, instead of the more standard Pearson correlation.

# %% [markdown]
# ## Generate the benchmark output
#
# Next, we process the test set the same way as we did on the train set and predict using our linear model, while saving the predictions to a csv file satisfying the challenge output contraints.

# %%
X_test.head()
# Out:
#      ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 0  1115     241      FR        0.340083       -0.433604       -0.423521
# 1  1202    1214      FR        0.803209        0.780411        0.601610
# 2  1194    1047      FR        0.795540        0.721954        1.179158
# 3  1084    1139      FR        0.172555       -0.723427       -0.044539
# 4  1135     842      FR        0.949714        0.420236        0.617391
#
#    FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  ...  \
# 0        0.423521       0.165333       0.519419      -0.165333  ...
# 1       -0.601610       0.342802       0.555367      -0.342802  ...
# 2       -1.179158       1.620928       0.666901      -1.620928  ...
# 3        0.044539            NaN      -0.205276            NaN  ...
# 4       -0.617391       0.608561      -0.240856      -0.608561  ...
#
#    FR_RESIDUAL_LOAD   DE_RAIN   FR_RAIN   DE_WIND   FR_WIND   DE_TEMP  \
# 0         -0.222525 -0.513180 -0.182048 -0.982546 -0.876632  0.880491
# 1          0.857739 -0.340595 -0.301094 -0.759816 -1.221443 -0.616617
# 2          0.447967  0.796475 -0.367248  0.376055 -0.483363  0.865138
# 3         -0.561295 -0.542606 -0.013291 -0.791119 -0.894309  0.239153
# 4          0.503567 -0.230291 -0.609203 -0.744986 -1.196282  0.176557
#
#     FR_TEMP   GAS_RET  COAL_RET  CARBON_RET
# 0  0.692242  0.569419 -0.029697   -0.929256
# 1 -0.737496  0.251251  0.753646    0.664086
# 2  0.120079 -1.485642 -0.326450   -0.349747
# 3  0.457457 -0.746863  2.262654    0.642069
# 4  0.312557 -2.219626 -0.509272   -0.488341
#
# [5 rows x 35 columns]

# %%
X_test_clean = X_test.drop(['COUNTRY'], axis=1).fillna(0)

Y_test_submission = X_test[['ID']].copy()
xtest  =scaler.fit_transform(X_test_clean)
Y_test_submission['TARGET'] = model.predict(xtest)

Y_test_submission.to_csv('benchmark_qrt1.csv', index=False)
# Out:
# 21/21 [==============================] - 0s 2ms/step

# %% [markdown]
# After submitting this benchmark_qrt.csv file at https://challengedata.ens.fr, we obtain a public score of around 15.9 % - this is the score to beat!

# %% [markdown]
# ## Tips and ideas for improvements
#
# - Thinking about the fundamental price drivers of electricity in each country may be useful.
#
# - The dataset is small, so you will need to be careful not to overfit your models. It will be useful to use good crossvalidation practices.
